# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline

# %%
churn=pd.read_csv('c:/Users/LENOVO/My Documents/data sets/Churn_MV.csv')

# %%
churn.head()
# Out:
#    Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0             NaN            NaN       NaN       NaN         NaN        NaN
# 1           128.0           25.0     265.1     197.4       244.7       10.0
# 2             NaN            NaN       NaN       NaN         NaN        NaN
# 3           107.0           26.0     161.6     195.5       254.4       13.7
# 4             NaN            NaN       NaN       NaN         NaN        NaN
#
#    CustServ Calls  Churn  Intl Plan  VMail Plan  ...  Daily Charges MV  \
# 0             NaN    NaN        NaN         NaN  ...               NaN
# 1             1.0    0.0        0.0         1.0  ...             45.07
# 2             NaN    NaN        NaN         NaN  ...               NaN
# 3             1.0    0.0        0.0         1.0  ...             27.47
# 4             NaN    NaN        NaN         NaN  ...               NaN
#
#    Eve Calls  Eve Charge  Night Calls  Night Charge  Intl Calls  Intl Charge  \
# 0        NaN         NaN          NaN           NaN         NaN          NaN
# 1       99.0       16.78         91.0         11.01         3.0          2.7
# 2        NaN         NaN          NaN           NaN         NaN          NaN
# 3      103.0       16.62        103.0         11.45         3.0          3.7
# 4        NaN         NaN          NaN           NaN         NaN          NaN
#
#    State  Area Code     Phone
# 0    NaN        NaN       NaN
# 1     KS      415.0  382-4657
# 2    NaN        NaN       NaN
# 3     OH      415.0  371-7191
# 4    NaN        NaN       NaN
#
# [5 rows x 22 columns]

# %%
churn.isnull().sum(axis=1)
# Out:
# 0       22
# 1        0
# 2       22
# 3        0
# 4       22
# 5        0
# 6       22
# 7        0
# 8       22
# 9        0
# 10      22
# 11       0
# 12      22
# 13       1
# 14      22
# 15       0
# 16      22
# 17       0
# 18      22
# 19       0
# 20      22
# 21       0
# 22      22
# 23       1
# 24      22
# 25       0
# 26      22
# 27       0
# 28      22
# 29       0
#         ..
# 6636    22
# 6637     0
# 6638    22
# 6639     0
# 6640    22
# 6641     0
# 6642    22
# 6643     0
# 6644    22
# 6645     0
# 6646    22
# 6647     0
# 6648    22
# 6649     0
# 6650    22
# 6651     0
# 6652    22
# 6653     0
# 6654    22
# 6655     0
# 6656    22
# 6657     0
# 6658    22
# 6659     0
# 6660    22
# 6661     0
# 6662    22
# 6663     0
# 6664    22
# 6665     0
# Length: 6666, dtype: int64

# %%
churn.dropna(axis=0,how='all',inplace=True)

# %%
churn.isnull().sum()
# Out:
# Account Length       0
# VMail Message        0
# Day Mins             0
# Eve Mins             0
# Night Mins           0
# Intl Mins            0
# CustServ Calls       0
# Churn                0
# Intl Plan            0
# VMail Plan           0
# Day Calls            0
# Day Charge           0
# Daily Charges MV    50
# Eve Calls            0
# Eve Charge           0
# Night Calls          0
# Night Charge         0
# Intl Calls           0
# Intl Charge          0
# State                0
# Area Code            0
# Phone                0
# dtype: int64

# %%
#heat map for null values
sns.heatmap(churn.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
churn.columns
# Out:
# Index(['Account Length', 'VMail Message', 'Day Mins', 'Eve Mins', 'Night Mins',
#        'Intl Mins', 'CustServ Calls', 'Churn', 'Intl Plan', 'VMail Plan',
#        'Day Calls', 'Day Charge', 'Daily Charges MV', 'Eve Calls',
#        'Eve Charge', 'Night Calls', 'Night Charge', 'Intl Calls',
#        'Intl Charge', 'State', 'Area Code', 'Phone'],
#       dtype='object')

# %%
median_value=churn['Daily Charges MV'].median()
churn['Daily Charges MV']=churn['Daily Charges MV'].fillna(median_value)

# %%
sns.jointplot(x='Day Charge',y='Daily Charges MV',data=churn,kind='reg')

# %%
churn.groupby('VMail Plan').sum()
# Out:
#             Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  \
# VMail Plan
# 0.0               243494.0            0.0  433574.5  482934.8    483844.2
# 1.0                93355.0        26994.0  165615.9  186932.7    185662.3
#
#             Intl Mins  CustServ Calls  Churn  Intl Plan  Day Calls  \
# VMail Plan
# 0.0           24687.6          3803.0  403.0      231.0   242482.0
# 1.0            9433.3          1406.0   80.0       92.0    92270.0
#
#             Day Charge  Daily Charges MV  Eve Calls  Eve Charge  Night Calls  \
# VMail Plan
# 0.0           73708.99          73622.67   241567.0    41049.88     240906.0
# 1.0           28155.18          28143.73    92114.0    15889.56      92753.0
#
#             Night Charge  Intl Calls  Intl Charge  Area Code
# VMail Plan
# 0.0             21773.24     10772.0      6666.84  1054094.0
# 1.0              8354.83      4158.0      2547.51   403035.0

# %%
churn.drop(['Daily Charges MV'],axis=1,inplace=True)

# %%
churn.columns
# Out:
# Index(['Account Length', 'VMail Message', 'Day Mins', 'Eve Mins', 'Night Mins',
#        'Intl Mins', 'CustServ Calls', 'Churn', 'Intl Plan', 'VMail Plan',
#        'Day Calls', 'Day Charge', 'Eve Calls', 'Eve Charge', 'Night Calls',
#        'Night Charge', 'Intl Calls', 'Intl Charge', 'State', 'Area Code',
#        'Phone'],
#       dtype='object')

# %%
d=churn[['Area Code','Phone','State']]

# %%
churn.drop(d,axis=1,inplace=True)

# %%
churn.columns
# Out:
# Index(['Account Length', 'VMail Message', 'Day Mins', 'Eve Mins', 'Night Mins',
#        'Intl Mins', 'CustServ Calls', 'Churn', 'Intl Plan', 'VMail Plan',
#        'Day Calls', 'Day Charge', 'Eve Calls', 'Eve Charge', 'Night Calls',
#        'Night Charge', 'Intl Calls', 'Intl Charge'],
#       dtype='object')

# %%
churn.Churn.value_counts()
# Out:
# 0.0    2850
# 1.0     483
# Name: Churn, dtype: int64

# %%
sns.countplot(x='CustServ Calls',hue='Churn',data=churn)

# %%
sns.countplot('Churn',data=churn)

# %%
sns.barplot(x='CustServ Calls',y='Day Charge',data=churn)

# %%
plt.figure(figsize=(10,6))
churn[churn['Churn']==1]['Day Charge'].hist(bins=35,color='blue',label='Churn 1',alpha=0.6)
churn[churn['Churn']==0]['Day Charge'].hist(bins=35,color='red',label='Churn 0',alpha=0.6)
plt.legend()
plt.xlabel('DAY CHARGE')
# Out:
# Text(0.5, 0, 'DAY CHARGE')

# %%
sns.boxplot(x='Churn',y='Account Length',data=churn)

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='Intl Plan',hue='Churn',data=churn)

# %%
plt.figure(figsize=(12,6))
churn[churn['Churn']==1]['Intl Charge'].hist(bins=35,color='blue',label='churn 1',alpha=0.6)
churn[churn['Churn']==0]['Intl Charge'].hist(bins=35,color='red',label='churn 0',alpha=0.6)
plt.legend()
plt.xlabel('INTL CHARGE')
# Out:
# Text(0.5, 0, 'INTL CHARGE')

# %%
sns.boxplot(x='Churn',y='Day Charge',data=churn)

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='VMail Plan',hue='Churn',data=churn)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(churn,hue='Churn',size=4)\
.map(plt.scatter,'Day Charge','Eve Charge',alpha=0.5)\
.add_legend();
plt.show()
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
